# %%
import pandas as pd

# %%
df = pd.read_csv('btc-market-price.csv')

# %%
df.head() # İlk 5 değer
# Out:
#                  Zaman        Değer
# 0  2017-04-03 00:00:00  1141.813000
# 1  2017-04-04 00:00:00  1141.600363
# 2  2017-04-05 00:00:00  1133.079314
# 3  2017-04-06 00:00:00  1196.307937
# 4  2017-04-07 00:00:00  1190.454250

# %%
df.columns = ["Zaman","Değer"]

# %%
df.head()
# Out:
#                  Zaman        Değer
# 0  2017-04-03 00:00:00  1141.813000
# 1  2017-04-04 00:00:00  1141.600363
# 2  2017-04-05 00:00:00  1133.079314
# 3  2017-04-06 00:00:00  1196.307937
# 4  2017-04-07 00:00:00  1190.454250

# %%
df["Zaman"] = pd.to_datetime(df["Zaman"])

# %%
df["Zaman"].head()
# Out:
# 0   2017-04-03
# 1   2017-04-04
# 2   2017-04-05
# 3   2017-04-06
# 4   2017-04-07
# Name: Zaman, dtype: datetime64[ns]

# %%
df.set_index("Zaman",inplace = True) # İndekseleme artık 0,1,2 ile değil zaman ile olacak

# %%
df.head()
# Out:
#                   Değer
# Zaman
# 2017-04-03  1141.813000
# 2017-04-04  1141.600363
# 2017-04-05  1133.079314
# 2017-04-06  1196.307937
# 2017-04-07  1190.454250

# %%
df.loc["2017-04-04"]
# Out:
# Değer    1141.600363
# Name: 2017-04-04 00:00:00, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
df.plot()
# Out:
# <AxesSubplot: xlabel='Zaman'>

# %%
plt.plot(df.index, df["Değer"])
